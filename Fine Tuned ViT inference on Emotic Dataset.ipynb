# %%
import torch

if torch.cuda.is_available():
    print("Current GPU:", torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print("No GPU available.")
# Out:
# Current GPU: NVIDIA A30

# %%
from transformers import AutoModelForImageClassification, AutoImageProcessor

# Specify the directory where the model is saved
model_directory = "Emotic_VIT_model_9_epoch.h5"

# Load the model
model = AutoModelForImageClassification.from_pretrained(model_directory)

# Load the image processor
processor = AutoImageProcessor.from_pretrained(model_directory)
# Out:
# 2024-10-10 11:26:28.332077: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# %matplotlib inline

import os
import numpy as np
import matplotlib.pyplot as plt

os.chdir("/homes/t326h379/laxman/img_arrs")

# Load the .npy file
array = np.load('crop_arr_test_9.npy')

# Print the contents of the array
print(array.shape)
plt.imshow(array)
plt.axis('off')
plt.show()
# Out:
# (224, 224, 3)

# %%
import pandas as pd
df_Independent_Test = pd.read_csv("/homes/t326h379/laxman/annots_arrs/annot_arrs_test.csv")

Emotions_of_corresponing_Independent_Test_Datset = np.array(df_Independent_Test.iloc[:,8:34])

Independent_Test_npy_names = list(df_Independent_Test["Crop_name"])
Independent_Test_jpg_names = [value.split(".")[0]+".jpg" for value in Independent_Test_npy_names]

Independent_Test_Dataset = []
# Load the .npy file
Base_Directory = "/homes/t326h379/laxman/img_arrs/jpg_folder"
for mason_values in Independent_Test_jpg_names:
    serena_images = Base_Directory+"/"+mason_values
    Independent_Test_Dataset.append(serena_images)

# %%
Independent_Test_Dataset
# Out:
# ['/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_0.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_1.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_2.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_3.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_4.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_5.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_6.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_7.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_8.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_9.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_10.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_11.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_12.jpg',
#  '/homes/t326h379/laxman/img_arrs/jpg_folder/crop_arr_test_13.jpg',
# ...
